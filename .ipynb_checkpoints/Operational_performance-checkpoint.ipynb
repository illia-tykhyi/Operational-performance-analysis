# %% [markdown]
# # Analysis of Customer Support Operational Performance

# %% [markdown]
# ## Ключові Висновки і Рекомендації

# %% [markdown]
# **Висновки**
# 1. **Продуктивність за ключовими показниками ефективності**
#
#    Служба підтримки не відповідає очікуванням керівництва щодо часу очікування клієнтів. Середній час відповіді становить приблизно 4286 хвилин, що значно перевищує цільовий показник у 15 хвилин.  Цілих 78,34% користувачів чекають довше, ніж критичний поріг у 45 хвилин, тоді як лише близько 8% отримують відповідь протягом цільового показника у 15 хвилин.
#     Натомість команда добре справляється з активною обробкою запитів після їх початку. Середній час обробки становить 2,24 хвилини, що цілком відповідає цільовому показнику у 5 хвилин. Лише 10,67% завдань займають більше часу, ніж зазначений ліміт. Це вказує на те, що основним проблемним місцем є тривала затримка перед початком роботи агентів над запитами, а не час, витрачений на самі завдання.
# 2. **Продуктивність агентів**
#
#    Невелика кількість агентів демонструє постійно високий час обробки. Модератори 150 та 133 перевищують середній показник часу обробки у 5 хвилин. Крім того, майже половина всіх агентів (23 агенти) має  понад 10% завдань оброблених довше 5 хвилин з помітною концентрацією на команді оптової торгівлі.
#    Робоче навантаження розподілене нерівномірно. 10% найкращих модераторів (5 агентів) обробляють майже 26% усіх вхідних запитів. Така залежність від кількох високопродуктивних фахівців створює ризик вигорання та підкреслює можливість вчитися на їхній ефективності.
#
# 3. **Системні недоліки та недоліки в плануванні**
#
#    Аналіз виявляє значну невідповідність між штатним розкладом та періодами пікових запитів. Для оптової команди проміжок високої активності клієнтів триває з 1 до 9 години ранку. Тоді як працівники починають свій робочий день з 7 ранку.
#    Обсяги запитів найвищі у п'ятницю та вихідні (субота, неділя), які також є днями з найдовшим часом відповіді, що вказує на нестачу персоналу.
#    Команди роздрібної та оптової торгівлі мають різні години пік. Попит у роздрібній торгівлі зростає між 7:00 та 14:00, тоді як оптові запити досягають піку набагато раніше, між 1:00 та 9:00, ймовірно, через міжнародні часові пояси клієнтів. Ця невідповідність між робочим часом та припливом запитів негативно впливає на час відповіді команди оптової торгівлі.
#    У годину пік служба отримує приблизно 30 запитів на годину. Зі середньою пропускною здатністю агентів близько 8 запитів на годину, команда погано оснащена для обробки попиту, що призводить до величезного накопичення замовлень та часу очікування. Потрібно щонайменше 4 високоефективних агентів, які працюють одночасно в ці години.
#
# 4. **Структура команди**
#
#    Команда оптової торгівлі постійно демонструє довший час обробки, що свідчить про те, що їхні завдання можуть бути складнішими, ніж у команди роздрібної торгівлі.
#    Дві команди стикаються з унікальними моделями попиту з різними годинами пік протягом дня. Це свідчить про те, що  об’єднання команд або універсальний підхід до планування та управління є неефективним.
#
# **Рекомендації**
#
# На основі цих висновків пропоную такі рекомендації на основі даних для покращення якості та ефективності служби підтримки клієнтів:
# 1.  **Реструктуризація графіків та збільшення штату**
#
#     Збільшення команди підтримки шляхом найму 4-5 додаткових агентів. Під час найму слід надавати пріоритет кандидатам, доступним для змін у вихідні дні та ранкових годин (наприклад, з 1:00 до 9:00), необхідних для належної підтримки команди оптової торгівлі.
#     Перерозподіл поточних графіків персоналу, щоб забезпечити краще покриття у визначені періоди пік. Це включає збільшення доступності агентів у п'ятницю, суботу та неділю, а також створення спеціальних змін, що відповідають годинам пік як для роздрібної (з 7:00 до 14:00), так і для оптової (з 1:00 до 9:00) команди. Забезпечення гнучкості графіків також може допомогти впоратися з неочікуваними змінами.
#
# 2. **Покращення продуктивності агентів та балансування робочого навантаження**
#
#    Потрібно дослідити продуктивність агентів зі стабільно високим часом обробки, особливо в команді оптової торгівлі. Забезпечити цільове навчання для усунення потенційних прогалин у знаннях або неефективності їхнього робочого процесу. Аналіз складності завдань оптової торгівлі може виявити потребу в більш спеціалізованих навчальних матеріалах або допоміжних ресурсах.
#    Потрібно вирішити проблему високої концентрації запитів, які обробляють найпродуктивніші агенти, за допомогою розподілення робочого навантаження більш рівномірно, щоб запобігти вигоранню. Можливо вивчити методи цих найпродуктивніших агентів, щоб встановити найкращі практики та створити навчальні програми, які можуть підвищити продуктивність усієї команди.
#
# 3. **Переоцінка структури команди та співпрацю**
#
#    Не можна об'єднувати команди роздрібної та оптової торгівлі. Різна складність завдань та окремі години пікового навантаження свідчать про те, що окремі команди є більш ефективними. Злиття, ймовірно, розмиє спеціалізовані знання та ускладнить планування.
#    Впроваджуючи ці рекомендації, можна вирішити першопричини низької якості обслуговування, значно скоротити час очікування клієнтів та рухатися до виконання та перевищення очікувань керівництва щодо операційної досконалості.

# %% [markdown]
# ## Introduction: The Business Problem

# %% [markdown]
# *The customer support service needs to be analyzed for Retail and Wholesale platforms due to a high volume of complaints regarding poor service quality.*
#
# The **primary goal** is to identify the root causes of inefficiency and provide data-driven recommendations to improve the customer experience.
#
# **Key Performance Indicators (KPIs) from Management:**
# - ***Target Average Answer Time:*** The average time from a new request to a response should be under 15 minutes.
# - ***Critical Waiting Time Threshold:*** Users should not wait longer than 45 minutes for a response.
# - ***Target Task Handle Time:*** An agent should complete a task within 5 minutes.
#
# **Key Questions to Answer:**
# 1. How well does the support service currently meet management expectations?
# 2. Which agents require attention to improve service quality?
# 3. Do we need to increase the size of the support team? By how much?
# 4. How should the support schedule be optimized?
# 5. Is there a potential benefit to merging the Retail and Wholesale teams?
# 6. What are the primary factors causing long response times?
# 7. How can we explain anomalous periods of poor performance?

# %% [markdown]
# ## Data Preparation and Initial Exploration

# %%
# First, we need to import the necessary libraries for data analysis and visualization.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
# Loading dataset (insert your path to the Data.csv)
data = pd.read_csv("")

# %% [markdown]
# ***To prepare the data for analysis, we will:***
#
# - Convert all time-related columns to the proper datetime format.
#
# - Calculate two critical metrics for each request:
#
#   answer_time: The time a user waits for an agent to start working on their request (in minutes).
#
#    handle_time: The time an agent actively spends working on the request (in minutes).
#
# - Extract useful time-based features like dayofweek and hour to analyze patterns.

# %%
# Converting time columns to datetime
for col in ['request_time', 'start_time', 'finish_time']:
    data[col] = pd.to_datetime(data[col])

# Checking if it worked
print(data.loc[:, 'request_time'].dtype)
# Out:
# datetime64[ns]

# %%
# Calculating 'answer_time' in minutes
data.loc[:, 'answer_time'] = (data.loc[:, 'start_time'] - data.loc[:, 'request_time']).dt.total_seconds() / 60

# Calculating 'work_time' in minutes
data.loc[:, 'handle_time'] = (data.loc[:, 'finish_time'] - data.loc[:, 'start_time']).dt.total_seconds() / 60

# %%
# Create useful variables
data['weekday'] = data['request_time'].dt.day_name()
data['weekday_start'] = data['start_time'].dt.day_name()
data['hour'] = data['request_time'].dt.hour
data['hour_start'] = data['start_time'].dt.hour
data['date'] = data['start_time'].dt.date
data['week'] = data['start_time'].dt.isocalendar().week

# %% [markdown]
# ### Initial Dataset Overview

# %%
# Preview the data
print(data.head())

print(data.info())
# Out:
#    moderator  id_request        request_time          start_time  \
# 0        165      159660 2020-09-24 07:01:16 2020-10-01 16:00:31
# 1        178      160116 2020-09-24 22:32:15 2020-10-01 13:21:42
# 2        187      160178 2020-09-25 02:58:13 2020-10-02 11:37:16
# 3        178      160306 2020-09-25 09:44:12 2020-10-02 07:23:09
# 4        178      163042 2020-09-30 15:56:08 2020-10-02 07:37:33
#
#           finish_time       team   answer_time  handle_time    weekday  \
# 0 2020-10-01 16:02:02     retail  10619.250000     1.516667   Thursday
# 1 2020-10-01 13:21:43     retail   9529.450000     0.016667   Thursday
# 2 2020-10-02 11:41:56  wholesale  10599.050000     4.666667     Friday
# 3 2020-10-02 07:25:33     retail   9938.950000     2.400000     Friday
# 4 2020-10-02 07:47:57     retail   2381.416667    10.400000  Wednesday
#
#   weekday_start  hour  hour_start        date  week
# 0      Thursday     7          16  2020-10-01    40
# ...

# %%
plt.figure(figsize=(15, 20))
plt.scatter(data['request_time'], data['answer_time'])

plt.xlabel("Request Time")
plt.ylabel("Answer Time")
plt.title("Request Time vs. Answer Time regardless of department")
plt.yticks(range(0, int(data['answer_time'].max()) + 1000, 1000))
plt.tight_layout()
plt.show()

# %%
# Analyzing timespan of the data
print("The earliest date of request is -", data['request_time'].min(), ". The last request was committed in -",data['request_time'].max())

# Calculating distribution of requests between departments
print("Percentage of requests received by wholesale department is -", round((len(data[data['team'] == 'wholesale'])/len(data))* 100,2),"%. Percentage of requests received by retail department is -",  round((len(data[data['team']== 'retail'])/len(data))*100,2), "%")

# Calculating the number of points
print("The dataset has a size of -",len(data), "points.")

# Number of unique moderators
print("Number of unique moderators is:", data['moderator'].nunique()) 

# Moderators distribution across teams
print("Number of moderators in wholesale department is:", data.loc[data['team'] == 'wholesale', 'moderator'].nunique(), ", in retail department is:", data.loc[data['team'] == 'retail', 'moderator'].nunique())
# Out:
# The earliest date of request is - 2020-09-24 07:01:16 . The last request was committed in - 2020-12-31 22:11:17
# Percentage of requests received by wholesale department is - 60.62 %. Percentage of requests received by retail department is - 39.38 %
# The dataset has a size of - 35617 points.
# Number of unique moderators is: 49
# Number of moderators in wholesale department is: 25 , in retail department is: 24

# %% [markdown]
# ## How Are We Performing Now? (Current State vs. KPIs)

# %% [markdown]
# This section directly addresses Question 1: How well does the support service meet management expectations?
# We will now calculate our overall performance against the three key KPIs defined by management.

# %%
# Calculating average answer time per day
avg_answer_t = data.groupby(data.loc[:, 'request_time'].dt.date)['answer_time'].mean()
print('Average answer time is: ', avg_answer_t.mean())

# Calculating amount of requests (in %) with answer time > 45 minutes
long_wait = round((data.loc[:, 'answer_time'] > 45).mean() * 100, 2)
print('The percentage of requests waiting longer than 45 min - ',long_wait,'%')

# 15 >= answer time <= 45
normal_wait = round(((data.loc[:, 'answer_time'] >= 15) & (data.loc[:, 'answer_time'] <= 45)).mean() * 100, 2)
print('The percentage of requests waiting between 15-45 min - ', normal_wait,'%')

# answer time <= 15
short_wait = round(((data.loc[:, 'answer_time']) <= 15).mean() * 100, 2)
print('The percentage of requests waiting less than 15 min - ',short_wait,'%')

# Calculating average work time
average_work_time = round(data.loc[:, 'handle_time'].mean(),2)
print('The average handle time is - ', average_work_time)

# Inspecting the amount of times work_time surpassed 5 min limit
long_work_time = round((data.loc[:, 'handle_time'] > 5).mean() * 100, 2)
print('The percentage of long handle time is - ',long_work_time, '%')
# Out:
# Average answer time is:  4286.122287089253
# The percentage of requests waiting longer than 45 min -  78.34 %
# The percentage of requests waiting between 15-45 min -  13.6 %
# The percentage of requests waiting less than 15 min -  8.06 %
# The average handle time is -  2.24
# The percentage of long handle time is -  10.67 %

# %% [markdown]
# So average customer waiting time is 4286 minutes,  which massively exceeds the 15-minute target.
# Support service barely meets management expectations as ~78% of requests are waiting for response more than 45 minutes which is unacceptable by management. Only ~8% of users receive a response within the target 15 minutes.
# As for request handling time, the team performs well here, average time is 2.24 minutes and only 10.67% of requests are handled more than 5 minutes.
#
# Summing up, the primary issue is not the time agents spend on tasks, but the extremely long time users have to wait before their issue is addressed. The support service is failing to meet management's expectations for response time.

# %% [markdown]
# ## Agent Performance Analysis

# %% [markdown]
# This section addresses Question 2: Which agents should you pay attention to?
# We'll analyze performance at the individual moderator level to identify both top performers and those who may need additional training or support.

# %% [markdown]
# ### Handle Time Efficiency

# %% [markdown]
# We identify agents whose average handle_time exceeds the 5-minute KPI.

# %%
# Calculating average response time per moderator
avg_handle_time_by_moderator = data.groupby('moderator')['handle_time'].mean()

 
uneffective_moderators = avg_handle_time_by_moderator[avg_handle_time_by_moderator > 5].sort_values()

 
number_of_uneffective_moderators = len(uneffective_moderators)

print("number of uneffective moderators is:", number_of_uneffective_moderators)

 
print("Avg. handle time of each moderator:", avg_handle_time_by_moderator)
# Out:
# number of uneffective moderators is: 2
# Avg. handle time of each moderator: moderator
# 102     1.855021
# 103     2.294161
# 109     1.520455
# 110     1.300000
# 111     1.831752
# 112     2.281130
# 114     2.584722
# 116     2.247816
# 117     1.710205
# 121     1.566771
# 122     3.047914
# 123     3.057289
# 125     2.654581
# 126     0.550000
# 128     2.247961
# 129     2.883333
# 133    10.716667
# 134     0.814583
# 135     2.395566
# 136     1.459772
# 138     0.200000
# 141     2.909490
# 143     2.699409
# 144     3.025137
# 146     2.993088
# 148     2.309942
# 149     4.351110
# 150     5.109375
# 152     1.702446
# 153     2.877347
# 156     1.684447
# 161     3.093923
# 163     3.433205
# 164     2.026745
# 165     1.455229
# 167     4.319994
# 170     2.428420
# 171     0.016667
# 172     1.883950
# 173     2.219032
# 175     3.755159
# 176     1.036862
# 178     2.338016
# 180     1.908463
# 181     2.795928
# 185     3.056000
# 186     2.008594
# ...

# %%
# Calculating percentile of effectively handled tasks across moderators in both teams
data['long_handle'] = data['handle_time'] > 5

task_handle_summary = data.groupby('moderator').agg(
    team=('team', 'first'),
    percent_long_requests=('long_handle', 'mean')
)

task_handle_summary['percent_long_requests'] = task_handle_summary['percent_long_requests'] * 100

task_handle_summary = task_handle_summary.sort_values('percent_long_requests', ascending=False)

print(task_handle_summary)
# Out:
#                 team  percent_long_requests
# moderator
# 150           retail              56.250000
# 133           retail              50.000000
# 149        wholesale              31.824234
# 167           retail              27.798507
# 175        wholesale              25.476190
# 185        wholesale              24.000000
# 163        wholesale              22.307692
# 114           retail              20.000000
# 146        wholesale              19.251925
# 122        wholesale              19.165580
# 153        wholesale              18.854415
# 161        wholesale              18.784530
# 144        wholesale              18.032787
# 187        wholesale              17.937972
# 181        wholesale              16.861538
# 123        wholesale              16.804408
# 141           retail              16.409537
# 143        wholesale              16.312057
# 125        wholesale              15.619546
# 170        wholesale              12.989324
# ...

# %% [markdown]
# ### Workload Distribution

# %%
# How many requests each moderator handle per day?
daily_counts = data.groupby(['moderator', 'date']).size().reset_index(name='daily_requests')
avg_daily = daily_counts.groupby('moderator')['daily_requests'].mean().reset_index(name='avg_requests_per_active_day')

print("How many requests each moderator handled per active day- ", avg_daily.sort_values(by='avg_requests_per_active_day'))


threshold = avg_daily['avg_requests_per_active_day'].quantile(0.90)
print("The 90th percentile is", threshold)


top_mods = avg_daily.loc[
    avg_daily['avg_requests_per_active_day'] >= threshold, 
    'moderator'
]


top_requests = data.loc[data['moderator'].isin(top_mods)].shape[0]


total_requests = len(data)
pct = top_requests / total_requests * 100

print("Top moderators are:")
print(top_mods.tolist())

print("Moderators in the top 10% are handling", pct, " of all requests daily.")
# Out:
# How many requests each moderator handled per active day-      moderator  avg_requests_per_active_day
# 3         110                     1.000000
# 15        129                     1.000000
# 20        138                     1.000000
# 37        171                     1.000000
# 16        133                     2.000000
# 13        126                     2.000000
# 17        134                     2.666667
# 27        150                     4.000000
# 6         114                    10.000000
# 23        144                    10.166667
# 22        143                    11.750000
# 32        163                    13.000000
# 31        161                    13.923077
# 40        175                    14.482759
# 14        128                    14.812500
# 28        152                    17.035714
# 35        167                    17.866667
# 39        173                    18.029412
# 4         111                    18.354839
# ...

# %% [markdown]
# Findings:
#
# Moderators 150 and 133 have an average handle time greater than 5 minutes. Furthermore, 23 agents (nearly half the team) have a "long handle rate" of over 10%, with most belonging to the wholesale team. This suggests that wholesale tasks may be more complex or that this team requires more support.
# The workload is highly concentrated. The top 10% of moderators (5 agents) handle daily nearly 26% of all requests. Moderator 188 alone handles more than double the requests of the next most active agent.
#
# In conclusion, we should investigate why specific agents, particularly on the wholesale team, have high handle times according to percent of long requests metric. Additionally, we need to understand the workload imbalance—are our top performers at risk of burnout? Can their efficiency be replicated across the team?

# %% [markdown]
# ## Systemic & Scheduling Issues

# %% [markdown]
# This section tackles Questions 3, 4, 6, and 7 by looking at systemic factors like workload patterns and staffing levels.

# %% [markdown]
# ### When is the Service Failing? (Weekly & Daily Patterns)

# %% [markdown]
# Analyzing the average number of requests and the average answer time by both the day of the week and the hour of the day to find busiest and most problematic periods.

# %%
# Average Answer Time per Weekday across teams
overall_answer = data.groupby('weekday')['answer_time'].mean().rename('avg_overall')

#  Across team
team_answer = data.pivot_table(
    index='weekday',
    columns='team',
    values='answer_time',
    aggfunc='mean'
)

# Combining
avg_answer_time_weekday = pd.concat([overall_answer, team_answer], axis=1)

# Order by day
weekday_order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
avg_answer_time_weekday = avg_answer_time_weekday.reindex(weekday_order)

print("Average Answer Time per Day of Week:", avg_answer_time_weekday)
# Out:
# Average Answer Time per Day of Week:            avg_overall      retail    wholesale
# weekday
# Monday     2611.552613  854.107399  3354.472635
# Tuesday    2254.163415  457.989539  3308.712953
# Wednesday  2593.134962  872.625225  3636.688046
# Thursday   1754.464714  429.323817  3159.285190
# Friday     2371.681013  532.051381  3590.041438
# Saturday   2804.634527  640.974254  4191.518255
# Sunday     2759.388279  570.562995  4144.689892

# %%
# Average number of requests per Active Weekday across teams
daily_counts = data.groupby(['date', 'weekday', 'team']).size().reset_index(name='daily_requests')

 
overall_req_count = daily_counts.groupby('weekday')['daily_requests'].mean().rename('avg_overall')

 
team_req_count = daily_counts.pivot_table(
    index='weekday',
    columns='team',
    values='daily_requests',
    aggfunc='mean'
) 

 
avg_weekday_req_count = pd.concat([overall_req_count, team_req_count], axis=1)

 
avg_weekday_req_count = avg_weekday_req_count.reindex(weekday_order)

print("Average Requests per Active Day of Week:", avg_weekday_req_count)
# Out:
# Average Requests per Active Day of Week:            avg_overall     retail  wholesale
# weekday
# Monday       49.235955  28.933333  70.000000
# Tuesday      47.859155  35.914286  59.472222
# Wednesday    56.021505  42.760870  69.000000
# Thursday     60.773810  67.358974  55.066667
# Friday       71.827160  56.536585  87.500000
# Saturday     66.329545  54.285714  77.326087
# Sunday       69.845238  55.463415  83.558140

# %%
# Count distinct moderators per hour
active_mods_by_hour = (
    data.groupby(['hour_start', 'team'])['moderator']
        .nunique()
        .rename("active_moderators")
)

print(active_mods_by_hour)
# Out:
# hour_start  team
# 0           wholesale     1
# 6           retail        2
#             wholesale     1
# 7           retail       17
#             wholesale    18
# 8           retail       16
#             wholesale    18
# 9           retail       17
#             wholesale    21
# 10          retail       18
#             wholesale    20
# 11          retail       19
#             wholesale    19
# 12          retail       17
#             wholesale    19
# 13          retail       16
#             wholesale    18
# 14          retail       17
#             wholesale    18
# 15          retail       12
#             wholesale    10
# 16          retail        8
#             wholesale     8
# 17          retail        8
#             wholesale     7
# 18          retail        7
#             wholesale     8
# 19          retail        7
#             wholesale     7
# 20          retail        7
#             wholesale     7
# 21          retail        6
# ...

# %%
# Count requests per day-hour-team
requests_per_hour_day_team = data.groupby(['date', 'hour', 'team']).size().reset_index(name='count')

 
average_requests_by_hour_team = requests_per_hour_day_team.pivot_table(
    index='hour',
    columns='team',
    values='count',
    aggfunc='mean'
)

print("Average requests per hour by team:")
print(average_requests_by_hour_team)
# Out:
# Average requests per hour by team:
# team     retail  wholesale
# hour
# 0      2.052632   7.953125
# 1      1.823529  19.421053
# 2      1.450000  23.539474
# 3      2.032258  25.301370
# 4      2.224490  13.180556
# 5      3.763889  15.932432
# 6      5.250000  19.987654
# 7      8.927711  22.887500
# 8     11.154762  30.612500
# 9     14.560976  22.101266
# 10    13.797619  10.974359
# 11    16.559524   9.974359
# 12    13.738095  10.144737
# 13    13.903614  11.200000
# 14    10.869048  11.175676
# 15     9.409639  10.565217
# 16     7.000000   6.298507
# 17     7.289157   4.073171
# 18     7.500000   2.621622
# 19     7.862500   2.555556
# 20     6.727273   4.393939
# 21     5.295082   5.250000
# 22     3.348485   4.586207
# 23     2.740000   4.387755

# %%
# Creating the heatmap
plt.figure(figsize=(15, 10))  
sns.heatmap(average_requests_by_hour_team, cmap='viridis', annot=True, fmt=".2f")  

# Adding labels and title
plt.xlabel('Requests number')
plt.ylabel('Hour')
plt.title('Hourly Average Number of Requests by team')

plt.tight_layout()
plt.show()

# %% [markdown]
# Findings:
# For weekly trends, the highest volume of requests occurs on Friday, Saturday, and Sunday. Correspondingly, the longest answer times are also on the weekend (Saturday and Sunday), indicating a  shortage of staff during these days.
# For hourly trends, the number of incoming requests peaks significantly between 7 AM and 2 PM for retail team. For the wholesale team number of requests peaks from 1 AM and 9 AM probably due to the differences in customers time-zone. One of the reasons the answer_time is higher for wholesale team because of disparity between wholesale team work hours and peak period of requests incoming. Also the number of requests in a hot time period is significantly higher for the wholesale team considering that the number of moderators is nearly the same.

# %% [markdown]
# ### Do We Need More Staff?

# %% [markdown]
# On average, a moderator handles about 27 requests per day. However, our busiest days (like Friday and Sunday) see over 100 requests

# %%
# How many requests on average each moderator takes daily/hourly
daily_counts = data.groupby(['moderator', 'date']).size().reset_index(name='daily_requests')
avg_daily = daily_counts.groupby('moderator')['daily_requests'].mean().reset_index(name='avg_requests_per_active_day')

hourly_counts = data.groupby(['moderator', 'date', 'hour_start']).size().reset_index(name='hourly_requests')
avg_hourly = hourly_counts.groupby('moderator')['hourly_requests'].mean().reset_index(name='avg_requests_per_hour')

# %%
print("Average hourly requests handled by average moderator", avg_hourly['avg_requests_per_hour'].mean())

# How much more efficient are top 10% moderators 
threshold_daily =  avg_daily.loc[:,'avg_requests_per_active_day'].quantile(0.90)

top_daily_req = avg_daily[avg_daily['avg_requests_per_active_day'] >= threshold_daily]['avg_requests_per_active_day'].mean()
total_daily_req = avg_daily.loc[:,'avg_requests_per_active_day'].mean()

pct_daily = top_daily_req / total_daily_req * 100

print("Moderators in the top 10% handle during the day ", pct_daily,"% more requests than average moderator.")
# Out:
# Average hourly requests handled by average moderator 8.002579958429857
# Moderators in the top 10% handle during the day  252.8951014529332 % more requests than average moderator.

# %% [markdown]
# Conclusion: With ~30 requests on peak hours and an average agent capacity of ~8 requests/hour, we would theoretically need 30 / 8 ≈ 4 highly efficient agents working simultaneously in each hour just to keep up. The data shows that we have around 20 active moderators each hour, but their low engagement or disparity in working-time to requests incoming peak time is not meeting the demand, leading to massive wait times.
#
# Recommendation: Yes, the support team should be increased, specifically to cover the weekend and morning shifts. A focused team of 4-5 additional agents could significantly reduce the backlog.

# %% [markdown]
# ## Is There a Benefit to Merging Teams?

# %% [markdown]
# This section directly addresses Question 5: Should we merge the Retail and Wholesale teams?
#
# By comparing the performance and workload patterns of the two teams, we can determine if a merger would create efficiencies.

# %%
# Plot average response time per day
avg_answer_t_w = data[data['team'] == 'wholesale'].groupby(data[data['team'] == 'wholesale'].loc[:, 'request_time'].dt.date)['answer_time'].mean()
avg_answer_t_r = data[data['team'] == 'retail'].groupby(data[data['team'] == 'retail'].loc[:, 'request_time'].dt.date)['answer_time'].mean()

# %%
plt.figure(figsize=(15, 10))
avg_answer_t_w.plot(label='Wholesale Response Time')
avg_answer_t_r.plot(label='Retail Response Time')
plt.axhline(15, color='red', linestyle='--', label='Management Expectation (15 min)')
plt.title('Average Response Time per Day (Wholesale and Retail)')
plt.ylabel('Average Response Time (minutes)')
plt.xlabel('Date')
plt.legend()
plt.grid(True)

plt.xticks(avg_answer_t_w.index[::2], rotation=45, ha='right')  # show every 2nd date
plt.show()

# %%
print(avg_weekday_req_count)
# Out:
#            avg_overall     retail  wholesale
# weekday
# Monday       49.235955  28.933333  70.000000
# Tuesday      47.859155  35.914286  59.472222
# Wednesday    56.021505  42.760870  69.000000
# Thursday     60.773810  67.358974  55.066667
# Friday       71.827160  56.536585  87.500000
# Saturday     66.329545  54.285714  77.326087
# Sunday       69.845238  55.463415  83.558140

# %%
# Define the order of weekdays
day_order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
avg_weekday_req_count = avg_weekday_req_count.reindex(day_order)

# Create the bar chart
plt.figure(figsize=(10, 6))
bar_width = 0.35

r1 = range(len(avg_weekday_req_count['wholesale']))
r2 = [x + bar_width for x in r1]

# Wholesale bars
plt.bar(r1, avg_weekday_req_count['wholesale'], width=bar_width, label='Wholesale department')

# Retail bars
plt.bar(r2, avg_weekday_req_count['retail'], width=bar_width, label='Retail department')

# Labels, title, aesthetic
plt.xlabel('Day of the Week')
plt.ylabel('Average Number of Requests')
plt.title('Average Number of Requests per Day of the Week')
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.xticks([r + bar_width / 2 for r in r1], day_order)

plt.tight_layout()
plt.legend()
plt.show()

# %% [markdown]
# Findings:
#
# - The wholesale team generally has longer handle times, percent of requests handled > 5 min(from task_handle_summary table), suggesting their tasks are more complex. The retail team faces a more volatile request volume.
#
# - Last month the wholesale team average answer time spiked up to 5000 min.
#
# - Teams see a surge in requests during different morning hours and on weekends.
